# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Colab Notebooks/Lemonade2016.csv'

# %%
df = pd.read_csv(path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         30 non-null     object
#  1   Location     30 non-null     object
#  2   Lemon        30 non-null     int64
#  3   Orange       30 non-null     int64
#  4   Temperature  30 non-null     int64
#  5   Leaflets     30 non-null     int64
#  6   Price        30 non-null     float64
#  7   Sales        30 non-null     int64
#  8   Revenue      30 non-null     float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 2.2+ KB

# %%
df.head()
# Out:
#      Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sales  \
# 0  7/1/16     Park     97      67           70        90   0.25    164
# 1  7/2/16     Park     98      67           72        90   0.25    165
# 2  7/3/16     Park    110      77           71       104   0.25    187
# 3  7/4/16    Beach    134      99           76        98   0.25    233
# 4  7/5/16    Beach    159     118           78       135   0.25    277
#
#    Revenue
# 0    41.00
# 1    41.25
# 2    46.75
# 3    58.25
# 4    69.25

# %%
df.loc[8, 'Date']="7/8/2016"

# %%
df['Leaflets'] = df['Leaflets']. fillna(round(df['Leaflets'].mean()))

# %%
df.drop_duplicates()
# Out:
#         Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sales  \
# 0     7/1/16     Park     97      67           70        90   0.25    164
# 1     7/2/16     Park     98      67           72        90   0.25    165
# 2     7/3/16     Park    110      77           71       104   0.25    187
# 3     7/4/16    Beach    134      99           76        98   0.25    233
# 4     7/5/16    Beach    159     118           78       135   0.25    277
# 5     7/6/16    Beach    103      69           82        90   0.25    172
# 6     7/7/16    Beach    143     101           81       135   0.25    244
# 7     7/8/16    Beach    123      86           82       113   0.25    209
# 8   7/8/2016    Beach    134      95           80       126   0.25    229
# 9    7/10/16    Beach    140      98           82       131   0.25    238
# 10   7/11/16    Beach    162     120           83       135   0.25    282
# 11   7/12/16    Beach    130      95           84        99   0.25    225
# 12   7/13/16    Beach    109      75           77        99   0.25    184
# 13   7/14/16    Beach    122      85           78       113   0.25    207
# 14   7/15/16    Beach     98      62           75       108   0.50    160
# 15   7/16/16    Beach     81      50           74        90   0.50    131
# 16   7/17/16    Beach    115      76           77       126   0.50    191
# 17   7/18/16     Park    131      92           81       122   0.50    223
# 18   7/19/16     Park    122      85           78       113   0.50    207
# 19   7/21/16     Park     83      50           77        90   0.50    133
# 20   7/22/16     Park    112      75           80       108   0.50    187
# 21   7/23/16     Park    120      82           81       117   0.50    202
# 22   7/24/16     Park    121      82           82       117   0.50    203
# 23   7/25/16     Park    156     113           84       135   0.50    269
# 24   7/26/16     Park    176     129           83       158   0.35    305
# 25   7/27/16     Park    104      68           80        99   0.35    172
# 26   7/28/16     Park     96      63           82        90   0.35    159
# 27   7/29/16     Park    100      66           81        95   0.35    166
# 28   7/30/16    Beach     88      57           82        81   0.35    145
# 29   7/31/16    Beach     76      47           82        68   0.35    123
#
#     Revenue
# 0     41.00
# 1     41.25
# 2     46.75
# 3     58.25
# 4     69.25
# 5     43.00
# 6     61.00
# 7     52.25
# 8     57.25
# 9     59.50
# 10    70.50
# 11    56.25
# 12    46.00
# 13    51.75
# 14    80.00
# 15    65.50
# 16    95.50
# 17   111.50
# 18   103.50
# 19    66.50
# 20    93.50
# 21   101.00
# 22   101.50
# 23   134.50
# 24   106.75
# 25    60.20
# 26    55.65
# 27    58.10
# 28    50.75
# 29    43.05

# %%
df.reset_index()
# Out:
#     index      Date Location  Lemon  Orange  Temperature  Leaflets  Price  \
# 0       0    7/1/16     Park     97      67           70        90   0.25
# 1       1    7/2/16     Park     98      67           72        90   0.25
# 2       2    7/3/16     Park    110      77           71       104   0.25
# 3       3    7/4/16    Beach    134      99           76        98   0.25
# 4       4    7/5/16    Beach    159     118           78       135   0.25
# 5       5    7/6/16    Beach    103      69           82        90   0.25
# 6       6    7/7/16    Beach    143     101           81       135   0.25
# 7       7    7/8/16    Beach    123      86           82       113   0.25
# 8       8  7/8/2016    Beach    134      95           80       126   0.25
# 9       9   7/10/16    Beach    140      98           82       131   0.25
# 10     10   7/11/16    Beach    162     120           83       135   0.25
# 11     11   7/12/16    Beach    130      95           84        99   0.25
# 12     12   7/13/16    Beach    109      75           77        99   0.25
# 13     13   7/14/16    Beach    122      85           78       113   0.25
# 14     14   7/15/16    Beach     98      62           75       108   0.50
# 15     15   7/16/16    Beach     81      50           74        90   0.50
# 16     16   7/17/16    Beach    115      76           77       126   0.50
# 17     17   7/18/16     Park    131      92           81       122   0.50
# 18     18   7/19/16     Park    122      85           78       113   0.50
# 19     19   7/21/16     Park     83      50           77        90   0.50
# 20     20   7/22/16     Park    112      75           80       108   0.50
# 21     21   7/23/16     Park    120      82           81       117   0.50
# 22     22   7/24/16     Park    121      82           82       117   0.50
# 23     23   7/25/16     Park    156     113           84       135   0.50
# 24     24   7/26/16     Park    176     129           83       158   0.35
# 25     25   7/27/16     Park    104      68           80        99   0.35
# 26     26   7/28/16     Park     96      63           82        90   0.35
# 27     27   7/29/16     Park    100      66           81        95   0.35
# 28     28   7/30/16    Beach     88      57           82        81   0.35
# 29     29   7/31/16    Beach     76      47           82        68   0.35
#
#     Sales  Revenue
# 0     164    41.00
# 1     165    41.25
# 2     187    46.75
# 3     233    58.25
# 4     277    69.25
# 5     172    43.00
# 6     244    61.00
# 7     209    52.25
# 8     229    57.25
# 9     238    59.50
# 10    282    70.50
# 11    225    56.25
# 12    184    46.00
# 13    207    51.75
# 14    160    80.00
# 15    131    65.50
# 16    191    95.50
# 17    223   111.50
# 18    207   103.50
# 19    133    66.50
# 20    187    93.50
# 21    202   101.00
# 22    203   101.50
# 23    269   134.50
# 24    305   106.75
# 25    172    60.20
# 26    159    55.65
# 27    166    58.10
# 28    145    50.75
# 29    123    43.05

# %%
df['Sales']=df['Lemon']+df['Orange']

# %%
df.plot.scatter(x=['Leaflets'],y=['Sales'])
plt.show()

# %%
df.hist(column=['Revenue'],bins=10)
plt.show()

# %%
df.boxplot(by=['Location'],column=['Sales'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
a = sns.boxplot(x='Location',y='Sales',data=df,palette='Set3')

# %%
data = df['Temperature']>=75
df[data]
# Out:
#         Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sales  \
# 3     7/4/16    Beach    134      99           76        98   0.25    233
# 4     7/5/16    Beach    159     118           78       135   0.25    277
# 5     7/6/16    Beach    103      69           82        90   0.25    172
# 6     7/7/16    Beach    143     101           81       135   0.25    244
# 7     7/8/16    Beach    123      86           82       113   0.25    209
# 8   7/8/2016    Beach    134      95           80       126   0.25    229
# 9    7/10/16    Beach    140      98           82       131   0.25    238
# 10   7/11/16    Beach    162     120           83       135   0.25    282
# 11   7/12/16    Beach    130      95           84        99   0.25    225
# 12   7/13/16    Beach    109      75           77        99   0.25    184
# 13   7/14/16    Beach    122      85           78       113   0.25    207
# 14   7/15/16    Beach     98      62           75       108   0.50    160
# 16   7/17/16    Beach    115      76           77       126   0.50    191
# 17   7/18/16     Park    131      92           81       122   0.50    223
# 18   7/19/16     Park    122      85           78       113   0.50    207
# 19   7/21/16     Park     83      50           77        90   0.50    133
# 20   7/22/16     Park    112      75           80       108   0.50    187
# 21   7/23/16     Park    120      82           81       117   0.50    202
# 22   7/24/16     Park    121      82           82       117   0.50    203
# 23   7/25/16     Park    156     113           84       135   0.50    269
# 24   7/26/16     Park    176     129           83       158   0.35    305
# 25   7/27/16     Park    104      68           80        99   0.35    172
# 26   7/28/16     Park     96      63           82        90   0.35    159
# 27   7/29/16     Park    100      66           81        95   0.35    166
# 28   7/30/16    Beach     88      57           82        81   0.35    145
# 29   7/31/16    Beach     76      47           82        68   0.35    123
#
#     Revenue
# 3     58.25
# 4     69.25
# 5     43.00
# 6     61.00
# 7     52.25
# 8     57.25
# 9     59.50
# 10    70.50
# 11    56.25
# 12    46.00
# 13    51.75
# 14    80.00
# 16    95.50
# 17   111.50
# 18   103.50
# 19    66.50
# 20    93.50
# 21   101.00
# 22   101.50
# 23   134.50
# 24   106.75
# 25    60.20
# 26    55.65
# 27    58.10
# 28    50.75
# 29    43.05

# %%
a1 = sns.boxplot(x='Location',y='Sales',data=df[data],palette='Set3')

# %%
sns.pairplot(data1,hue='Location')
plt.show()
